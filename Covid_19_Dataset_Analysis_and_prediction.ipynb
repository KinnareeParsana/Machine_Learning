# %% [markdown]
# Part-1

# %%
import numpy as np  
import matplotlib.pyplot as plt 
import pandas as pd 
import math

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/"My Drive/Colab Notebooks/"
# Out:
# /content/drive/My Drive/Colab Notebooks

# %%
dataset = pd.read_csv('time_series_covid19_confirmed_global.csv')
dataset1 = pd.read_csv('time_series_covid19_deaths_global.csv')
dataset2 = pd.read_csv('time_series_covid19_recovered_global.csv')

# %%
dataset.head()
# Out:
#   Province/State Country/Region       Lat  ...  5/1/21  5/2/21  5/3/21
# 0            NaN    Afghanistan  33.93911  ...   59939   60122   60300
# 1            NaN        Albania  41.15330  ...  131185  131238  131276
# 2            NaN        Algeria  28.03390  ...  122311  122522  122717
# 3            NaN        Andorra  42.50630  ...   13232   13282   13295
# 4            NaN         Angola -11.20270  ...   26815   26993   27133
#
# [5 rows x 472 columns]

# %%
dataset1.head()
# Out:
#   Province/State Country/Region       Lat  ...  5/1/21  5/2/21  5/3/21
# 0            NaN    Afghanistan  33.93911  ...    2631    2637    2642
# 1            NaN        Albania  41.15330  ...    2396    2397    2399
# 2            NaN        Algeria  28.03390  ...    3261    3270    3280
# 3            NaN        Andorra  42.50630  ...     125     127     127
# 4            NaN         Angola -11.20270  ...     600     602     603
#
# [5 rows x 472 columns]

# %%
dataset2.head()
# Out:
#   Province/State Country/Region       Lat  ...  5/1/21  5/2/21  5/3/21
# 0            NaN    Afghanistan  33.93911  ...   53272   53391   53391
# 1            NaN        Albania  41.15330  ...  110172  110920  111792
# 2            NaN        Algeria  28.03390  ...   85249   85398   85534
# 3            NaN        Andorra  42.50630  ...   12684   12753   12793
# 4            NaN         Angola -11.20270  ...   23913   23913   24190
#
# [5 rows x 472 columns]

# %%
dataset=pd.DataFrame(dataset)

# %%
dataset
# Out:
#     Province/State      Country/Region        Lat  ...  5/1/21  5/2/21  5/3/21
# 0              NaN         Afghanistan  33.939110  ...   59939   60122   60300
# 1              NaN             Albania  41.153300  ...  131185  131238  131276
# 2              NaN             Algeria  28.033900  ...  122311  122522  122717
# 3              NaN             Andorra  42.506300  ...   13232   13282   13295
# 4              NaN              Angola -11.202700  ...   26815   26993   27133
# ..             ...                 ...        ...  ...     ...     ...     ...
# 270            NaN             Vietnam  14.058324  ...    2942    2962    2985
# 271            NaN  West Bank and Gaza  31.952200  ...  296462  297638  298203
# 272            NaN               Yemen  15.552727  ...    6325    6341    6363
# 273            NaN              Zambia -13.133897  ...   91670   91693   91722
# 274            NaN            Zimbabwe -19.015438  ...   38260   38281   38293
#
# ...

# %%
dataset1=pd.DataFrame(dataset1)

# %%
dataset2=pd.DataFrame(dataset2)

# %%
dataset_i = dataset.loc[dataset['Country/Region']=='India']
dataset_i0 = dataset_i.drop(['Province/State','Country/Region','Lat','Long'],axis=1)

# %%
dataset_i0.head()
# Out:
#      1/22/20  1/23/20  1/24/20  1/25/20  ...   4/30/21    5/1/21    5/2/21    5/3/21
# 147        0        0        0        0  ...  19164969  19557457  19925517  19925604
#
# [1 rows x 468 columns]

# %%
dataset1_i = dataset1.loc[dataset1['Country/Region']=='India']
dataset1_i1 = dataset1_i.drop(['Province/State','Country/Region','Lat','Long'],axis=1) 
dataset1_i1
# Out:
#      1/22/20  1/23/20  1/24/20  1/25/20  ...  4/30/21  5/1/21  5/2/21  5/3/21
# 147        0        0        0        0  ...   211853  215542  218959  218959
#
# [1 rows x 468 columns]

# %%
dataset2_i = dataset2.loc[dataset2['Country/Region']=='India']
dataset2_i2 = dataset2_i.drop(['Province/State','Country/Region','Lat','Long'],axis=1) 
dataset2_i2
# Out:
#      1/22/20  1/23/20  1/24/20  1/25/20  ...   4/30/21    5/1/21    5/2/21    5/3/21
# 132        0        0        0        0  ...  15684406  15992271  16292725  16293003
#
# [1 rows x 468 columns]

# %%
dataset_i0.index=["Confirmed"]
m0=dataset_i0.transpose()
m0['Confirmed'] = m0

# %%
dataset1_i1.index=["Deaths"]
m1=dataset1_i1.transpose()
m0['Deaths'] = m1

# %%
dataset2_i2.index=["Recovred"]
m2=dataset2_i2.transpose()
m0['Recovred'] = m2

# %%
plt.plot(m0.index,m0['Confirmed'],label="confirmed")
plt.legend()
plt.show()

# %%
plt.plot(m0.index,m0['Deaths'],label="death")
plt.legend()
plt.show()

# %%
plt.plot(m0.index,m0['Confirmed'],label="confirmed",color="Blue")
plt.plot(m0.index,m0['Deaths'],label="death",color="red")
plt.plot(m0.index,m0['Recovred'],label="recovred",color="Green")
plt.legend()
plt.show()

# %% [markdown]
# Part-2

# %%
dataset=pd.DataFrame(dataset)

# %%
dataset1=pd.DataFrame(dataset1)

# %%
dataset2=pd.DataFrame(dataset2)

# %%
dataset_us = dataset.loc[dataset['Country/Region']=='US']
dataset_us0 = dataset_us.drop(['Province/State','Country/Region','Lat','Long'],axis=1) 
dataset_us0
# Out:
#      1/22/20  1/23/20  1/24/20  1/25/20  ...   4/30/21    5/1/21    5/2/21    5/3/21
# 250        1        1        2        2  ...  32346971  32392274  32421641  32470920
#
# [1 rows x 468 columns]

# %%
dataset1_us = dataset1.loc[dataset1['Country/Region']=='US']
dataset1_us1 = dataset1_us.drop(['Province/State','Country/Region','Lat','Long'],axis=1) 
dataset1_us1
# Out:
#      1/22/20  1/23/20  1/24/20  1/25/20  ...  4/30/21  5/1/21  5/2/21  5/3/21
# 250        0        0        0        0  ...   576328  576722  577045  577500
#
# [1 rows x 468 columns]

# %%
dataset2_us = dataset2.loc[dataset2['Country/Region']=='US']
dataset2_us2 = dataset2_us.drop(['Province/State','Country/Region','Lat','Long'],axis=1) 
dataset2_us2
# Out:
#      1/22/20  1/23/20  1/24/20  1/25/20  ...  4/30/21  5/1/21  5/2/21  5/3/21
# 235        0        0        0        0  ...        0       0       0       0
#
# [1 rows x 468 columns]

# %%
dataset_us0.index=["Confirmed"]
u0=dataset_us0.transpose()
u0['Confirmed'] = u0

# %%
dataset1_us1.index=["Deaths"]
us1=dataset1_us1.transpose()
u0['Deaths'] = us1

# %%
dataset2_us2.index=["Recovred"]
us2=dataset2_us2.transpose()
u0['Recovred'] = us2

# %%
plt.plot(u0.index,u0['Confirmed'],label="confirmed",color="Blue")
plt.plot(u0.index,u0['Deaths'],label="death",color="red")
plt.plot(u0.index,u0['Recovred'],label="recovred",color="Green")
plt.legend()
plt.show()

# %%
dataset_it = dataset.loc[dataset['Country/Region']=='Italy']
dataset_it0 = dataset_it.drop(['Province/State','Country/Region','Lat','Long'],axis=1) 
dataset_it0
# Out:
#      1/22/20  1/23/20  1/24/20  1/25/20  ...  4/30/21   5/1/21   5/2/21   5/3/21
# 153        0        0        0        0  ...  4022653  4035617  4044762  4050708
#
# [1 rows x 468 columns]

# %%
dataset1_it = dataset1.loc[dataset1['Country/Region']=='Italy']
dataset1_it1 = dataset1_it.drop(['Province/State','Country/Region','Lat','Long'],axis=1) 
dataset1_it1
# Out:
#      1/22/20  1/23/20  1/24/20  1/25/20  ...  4/30/21  5/1/21  5/2/21  5/3/21
# 153        0        0        0        0  ...   120807  121033  121177  121433
#
# [1 rows x 468 columns]

# %%
dataset2_it = dataset2.loc[dataset2['Country/Region']=='Italy']
dataset2_it2 = dataset2_it.drop(['Province/State','Country/Region','Lat','Long'],axis=1) 
dataset2_it2
# Out:
#      1/22/20  1/23/20  1/24/20  1/25/20  ...  4/30/21   5/1/21   5/2/21   5/3/21
# 138        0        0        0        0  ...  3465576  3484042  3492679  3505717
#
# [1 rows x 468 columns]

# %%
dataset_it0.index=["Confirmed"]
it0=dataset_it0.transpose()
it0['Confirmed'] = it0

# %%
dataset1_it1.index=["Deaths"]
it1=dataset1_it1.transpose()
it0['Deaths'] = it1

# %%
dataset2_it2.index=["Recovred"]
it2=dataset2_it2.transpose()
it0['Recovred'] = it2

# %%
plt.plot(it0.index,it0['Confirmed'],label="confirmed",color="Blue")
plt.plot(it0.index,it0['Deaths'],label="death",color="red")
plt.plot(it0.index,it0['Recovred'],label="recovred",color="Green")
plt.legend()
plt.show()

# %% [markdown]
# Part-3

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# %%
dataset_i = dataset.loc[dataset['Country/Region']=='India']
dataset_i
# Out:
#     Province/State Country/Region        Lat  ...    5/1/21    5/2/21    5/3/21
# 147            NaN          India  20.593684  ...  19557457  19925517  19925604
#
# [1 rows x 472 columns]

# %%
Xf = np.array(range(1,469))
Xf = Xf.reshape(-1,1)
Y = np.array(m0['Confirmed'])
Y = Y.reshape(-1,1)

# %%
x= np.array([468]).reshape(-1,1)

# %%
polynom_f = PolynomialFeatures(degree = 10)
Xpoly =((polynom_f.fit_transform(Xf))+1)
polynom_f = polynom_f.fit(Xpoly, Y)
lin = LinearRegression()
lin.fit(Xpoly, Y)
ans =int(lin.predict(polynom_f.fit_transform(x))) 
print(" Cases on 4th May, 2021:",ans)
# Out:
#  Cases on 4th May, 2021: 19855869

# %%
cases=ans- Y[-1]
cases
# Out:
# array([-69735])

# %% [markdown]
# Task-4

# %%
import os
import glob
location="data"

file_name=[]
for file in os.listdir(location):
        file_name.append(file)
      
print(file_name)
alldata=pd.concat([pd.read_csv("data/"+f) for f in file_name])
alldata.to_csv("alldata.csv",index=False,encoding='utf-8-sig')
# Out:
# ['03-01-2021.csv', '03-02-2021.csv', '03-03-2021 (1).csv', '03-03-2021.csv', '03-04-2021.csv', '03-05-2021.csv', '03-06-2021.csv', '03-07-2021.csv', '03-08-2021.csv', '03-09-2021 (1).csv', '03-09-2021.csv', '03-10-2021.csv', '03-11-2021.csv', '03-12-2021.csv', '03-16-2021.csv', '03-17-2021.csv', '03-18-2021.csv', '03-19-2021.csv', '03-20-2021.csv', '03-21-2021.csv', '03-22-2021.csv', '03-23-2021.csv', '03-24-2021.csv', '03-25-2021.csv', '03-26-2021.csv', '03-27-2021.csv', '03-28-2021.csv', '03-29-2021.csv', '03-30-2021.csv', '03-31-2021.csv', '03-13-2021.csv', '03-14-2021.csv', '03-15-2021.csv', '04-15-2021.csv', '04-16-2021.csv', '04-17-2021.csv', '04-18-2021.csv', '04-01-2021.csv', '04-02-2021.csv', '04-03-2021.csv', '04-04-2021 (1).csv', '04-04-2021.csv', '04-05-2021 (1).csv', '04-05-2021.csv', '04-06-2021.csv', '04-07-2021 (1).csv', '04-07-2021.csv', '04-08-2021.csv', '04-09-2021.csv', '04-10-2021 (1).csv', '04-10-2021.csv', '04-11-2021.csv', '04-12-2021.csv', '04-13-2021.csv', '
# ...

# %%
alldata
# Out:
#       FIPS Admin2  ... Incident_Rate Case_Fatality_Ratio
# 0      NaN    NaN  ...    143.168187            4.385194
# 1      NaN    NaN  ...   3750.469108            1.682556
# 2      NaN    NaN  ...    258.272078            2.637411
# 3      NaN    NaN  ...  14093.056364            1.010194
# 4      NaN    NaN  ...     63.451074            2.435984
# ...    ...    ...  ...           ...                 ...
# 3978   NaN    NaN  ...      3.008057            1.195355
# 3979   NaN    NaN  ...   5811.366883            1.095925
# 3980   NaN    NaN  ...     21.179531           19.407947
# 3981   NaN    NaN  ...    498.184395            1.365929
# 3982   NaN    NaN  ...    257.398829            4.095982
#
# [286776 rows x 14 columns]

# %%
data_g = alldata.loc[alldata['Province_State']=='Gujarat']
plt.plot(data_g['Last_Update'], data_g['Confirmed'], label = "Confirmed Cases",color="blue")
plt.plot(data_g['Last_Update'], data_g['Recovered'], label = "Recovered Cases", color = "green")
plt.plot(data_g['Last_Update'], data_g['Deaths'], label = "Deaths", color="red")
plt.xlabel("Days")
plt.ylabel("Number of Cases")
plt.title("Gujarat Covid Cases")
plt.legend()
plt.show()

# %% [markdown]
# TAsk-5

# %%
x_g = np.array(range(1,15))
x_g = x_g.reshape(-1,1)
y_g = np.array(gujaratdata['Confirmed'])
y_g = y_g.reshape(-1,1)
x_g.size
# Out:
# 14

# %%
polynom_f = PolynomialFeatures(degree = 5)
x_p= polynom_f.fit_transform(x_g)
polynom_f = polynom_f.fit(x_p, y_g)
lin2 = LinearRegression()
lin2.fit(x_p, y_g)
x = np.array([65]).reshape(-1, 1)
prediction =int(lin2.predict(polynom_f.fit_transform(x))) 
print(prediction)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-202-34a80da0b29d> in <module>()
#       3 polynom_f = polynom_f.fit(x_p, y_g)
#       4 lin2 = LinearRegression()
# ----> 5 lin2.fit(x_p, y_g)
#       6 x = np.array([65]).reshape(-1, 1)
#       7 prediction =int(lin2.predict(polynom_f.fit_transform(x)))
#
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     490         n_jobs_ = self.n_jobs
#     491         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 492                          y_numeric=True, multi_output=True)
#     493
#     494         if sample_weight is not None:
#
# ...

# %%
cases_g=ans-y_g[-1]
cases_g
# Out:
# array([19288092])

# %% [markdown]
# Task-6

# %%
print("Cases all over India on 4th May,2021 : ",cases)
print("Cases in Gujarat on 4th May,2021 : ",cases_g)
perct = (cases_g[0]/(cases[0]+cases_g[0]))*100
plt.pie([perct.round(2),100-perct.round(2)],colors=['orange','red'],labels=['Gujarat','India'],
        explode=(0.2,0),shadow=True,autopct='%1.1f%%')
plt.title("Covid cases on 4th May")
plt.legend()
plt.show()
# Out:
# Cases all over India on 4th May,2021 :  [-69735]
# Cases in Gujarat on 4th May,2021 :  [19288092]

# %% [markdown]
# Task-7

# %%
data_b = alldata.loc[alldata['Province_State']=='West Bengal']
plt.plot(data_b['Last_Update'], data_b['Confirmed'], label = "Confirmed Cases", color="blue")
plt.plot(data_b['Last_Update'], data_b['Recovered'], label = "Recovered Cases", color="green")
plt.plot(data_b['Last_Update'], data_b['Deaths'], label = "Deaths", color="red")
plt.xlabel("Days")
plt.ylabel("# Cases")
plt.title("West Bengal")
plt.legend()
plt.show()
